# %%
import pandas as pd
df = pd.read_excel("C:\\Users\\amanm\\Desktop\\IPL2023Matches.xlsx",index_col=None)

# %%
df
# Out:
#     Index        Team 1       Team 2        Winner     Margin  \
# 0       0        Titans  Super Kings        Titans  5 wickets
# 1       1  Punjab Kings          KKR  Punjab Kings     7 runs
# 2       2  Super Giants     Capitals  Super Giants    50 runs
# 3       3     Sunrisers       Royals        Royals    72 runs
# 4       4           RCB       Mumbai           RCB  8 wickets
# ..    ...           ...          ...           ...        ...
# 69     69           RCB       Titans        Titans  6 wickets
# 70     70   Super Kings       Titans   Super Kings    15 runs
# 71     71  Super Giants       Mumbai        Mumbai    81 runs
# 72     72        Titans       Mumbai        Titans    62 runs
# 73     73        Titans  Super Kings   Super Kings  5 wickets
#
#               Ground       Match Date Scorecard
# 0    Ahmedabad (840)     Mar 31, 2023  Twenty20
# 1      Mohali (1015)      Apr 1, 2023  Twenty20
# 2     Lucknow (3355)      Apr 1, 2023  Twenty20
# ...

# %%
df1 = pd.read_excel("C:\\Users\\amanm\\Desktop\\batting_IPL2023.xlsx")

# %%
df1
# Out:
#       Position to bat           BATTING                Dismissal   R   B   M  \
# 0                   0     Devon Conway          b Mohammed Shami   1   6   -
# 1                   1  Ruturaj Gaikwad   c Shubman Gill b Joseph  92  50   -
# 2                   2        Moeen Ali     c †Saha b Rashid Khan  23  17   -
# 3                   3       Ben Stokes     c †Saha b Rashid Khan   7   6   -
# 4                   4    Ambati Rayudu                  b Little  12  12   -
# ...               ...               ...                      ...  ..  ..  ..
# 1176                2      Shivam Dube                  not out   32  21  49
# 1177                3   Ajinkya Rahane        c Shankar b Sharma  27  13  20
# 1178                4    Ambati Rayudu              c & b Sharma  19   8   8
# 1179                5     MS Dhoni (c)†        c Miller b Sharma   0   1   1
# 1180                6  Ravindra Jadeja                  not out   15   6  14
#
# ...

# %%
df1.head(20)
# Out:
#     Position to bat             BATTING                        Dismissal   R  \
# 0                 0       Devon Conway                  b Mohammed Shami   1
# 1                 1    Ruturaj Gaikwad           c Shubman Gill b Joseph  92
# 2                 2          Moeen Ali             c †Saha b Rashid Khan  23
# 3                 3         Ben Stokes             c †Saha b Rashid Khan   7
# 4                 4      Ambati Rayudu                          b Little  12
# 5                 5        Shivam Dube    c Rashid Khan b Mohammed Shami  19
# 6                 6    Ravindra Jadeja                c Shankar b Joseph   1
# 7                 7       MS Dhoni (c)†                         not out   14
# 8                 8   Mitchell Santner                          not out    1
# 9                 0   Wriddhiman Saha †             c Dube b Hangargekar  25
# 10                1       Shubman Gill             c Gaikwad b Deshpande  63
# ...

# %%
df2 = pd.read_excel("C:\\Users\\amanm\\Desktop\\team.xlsx",index_col = None)

# %%
df2
# Out:
#       0  Unnamed: 1           MS Dhoni  Age:  41y 131d  Batting:  \
# 0     1         NaN       Devon Conway  Age:  31y 130d  Batting:
# 1     2         NaN    Ruturaj Gaikwad  Age:  25y 288d  Batting:
# 2     3         NaN     Ajinkya Rahane  Age:  34y 162d  Batting:
# 3     4         NaN      Shaik Rasheed  Age:   18y 52d  Batting:
# 4     5         NaN      Ambati Rayudu  Age:   37y 53d  Batting:
# ..   ..         ...                ...   ...       ...       ...
# 256  20         NaN  Bhuvneshwar Kumar  Age:  32y 283d  Batting:
# 257  21         NaN    Mayank Markande  Age:    25y 4d  Batting:
# 258  22         NaN        T Natarajan  Age:  31y 225d  Batting:
# 259  23         NaN        Adil Rashid  Age:  34y 271d  Batting:
# 260  24         NaN        Umran Malik  Age:  22y 358d  Batting:
#
#      Right hand Bat  Bowling:    Right arm Medium  CSK
# 0     Left hand Bat  Bowling:    Right arm Medium  CSK
# 1    Right hand Bat  Bowling:  Right arm Offbreak  CSK
# ...
